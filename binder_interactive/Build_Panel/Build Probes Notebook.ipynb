# %% [markdown]
# # Categorize Custom CIViC Variants and Generate Coordiantes

# %% [markdown]
# Welcome to OpenCAP Jupyter Notebooks! Here you can run pre-designed code to generate required files for custom capture panels.
#
# To run Jupyter notebook cells hold-down on "shift" and select "enter".

# %% [markdown]
# ## Commands to generate probes

# %% [markdown]
# We have created a python script called CIViC_variants_to_probes.py that will take in variants of interest generated from the CIViC interface and output a list of genomic coordinates that require capture. The output from this command can be provided to a commercial entitiy that generate probes for custom capture.
#
# Before running this cell, please upload your CIViC variants to the home directory (see ReadTheDocs) and change the input variant list name to match your variant list. You can run the cell by holding the "shift" key and selecting "enter".

# %%
#run command  python code             #input variant list
# %run -i 'CIViC_variants_to_probes.py' 'CIViC_variants_2019-04-05T14_04_07.csv'
# Out:
# Gene                                                              ERBB2
# Variant Name                                              AMPLIFICATION
# Variant Group(s)                                                    NaN
# Variant Types(s)                               Transcript Amplification
# Description           Her2 (ERBB2) amplifications are seen in up to ...
# Chromosome 1                                                         17
# Chromosome 1 Start                                             37856333
# Chromosome 1 Stop                                              37884915
# Chromosome 2                                                        NaN
# Chromosome 2 Start                                                  NaN
# Chromosome 2 Stop                                                   NaN
# Reference Build                                                  GRCh37
# Name: 0, dtype: object
# Gene                                                               BRAF
# Variant Name                                                      V600E
# Variant Group(s)                                                    NaN
# Variant Types(s)                                       Missense Variant
# Description           BRAF V600E has been shown to be recurrent in m...
# Chromosome 1                                                          7
# Chromosome 1 Start                                            140453136
# Chromosome 1 Stop                                             140453136
# Chromosome 2                                                        NaN
# Chromosome 2 Start                                                  NaN
# Chromosome 2 Stop                                                   NaN
# Reference Build                                                  GRCh37
# Name: 1, dtype: object
# Gene                                                               IDH1
# Variant Name                                                       R132
# Variant Group(s)                                                    NaN
# Variant Types(s)                               Protein Altering Variant
# Description           IDH1 R132 mutations have been observed in a nu...
# Chromosome 1                                                          2
# Chromosome 1 Start                                            209113111
# Chromosome 1 Stop                                             209113113
# Chromosome 2                                                        NaN
# Chromosome 2 Start                                                  NaN
# Chromosome 2 Stop                                                   NaN
# Reference Build                                                  GRCh37
# Name: 2, dtype: object
# Gene                                                               IDH2
# Variant Name                                                       R172
# Variant Group(s)                                                    NaN
# Variant Types(s)                               Protein Altering Variant
# Description           IDH2 R172 is a gain-of-function mutation commo...
# Chromosome 1                                                         15
# Chromosome 1 Start                                             90631837
# Chromosome 1 Stop                                              90631839
# Chromosome 2                                                        NaN
# Chromosome 2 Start                                                  NaN
# Chromosome 2 Stop                                                   NaN
# Reference Build                                                  GRCh37
# Name: 3, dtype: object
# Gene                               VHL
# Variant Name           S65W (c.194C>G)
# Variant Group(s)                   NaN
# Variant Types(s)      Missense Variant
# Description                        NaN
# Chromosome 1                         3
# Chromosome 1 Start            10183725
# Chromosome 1 Stop             10183725
# Chromosome 2                       NaN
# Chromosome 2 Start                 NaN
# Chromosome 2 Stop                  NaN
# Reference Build                 GRCh37
# Name: 4, dtype: object
# Gene                                                               NRAS
# Variant Name                                                        Q61
# Variant Group(s)                                                    NaN
# Variant Types(s)                                       Missense Variant
# Description           NRAS Q61 mutations have been found in multiple...
# Chromosome 1                                                          1
# Chromosome 1 Start                                            115256528
# Chromosome 1 Stop                                             115256530
# Chromosome 2                                                        NaN
# Chromosome 2 Start                                                  NaN
# Chromosome 2 Stop                                                   NaN
# Reference Build                                                  GRCh37
# Name: 5, dtype: object
# Gene                                                               BRAF
# Variant Name                                                       V600
# Variant Group(s)                                           Other V600's
# Variant Types(s)                               Protein Altering Variant
# Description           BRAF mutations of the valine 600 residue have ...
# Chromosome 1                                                          7
# Chromosome 1 Start                                            140453136
# Chromosome 1 Stop                                             140453137
# Chromosome 2                                                        NaN
# Chromosome 2 Start                                                  NaN
# Chromosome 2 Stop                                                   NaN
# Reference Build                                                  GRCh37
# Name: 6, dtype: object
# Gene                                                              BRCA1
# Variant Name                                           LOSS-OF-FUNCTION
# Variant Group(s)                                 BRCA Germline Variants
# Variant Types(s)       Loss Of Function Variant, Loss Of Heterozygosity
# Description           BRCA1 loss of function mutations have been sho...
# Chromosome 1                                                         17
# Chromosome 1 Start                                             41196312
# Chromosome 1 Stop                                              41277387
# Chromosome 2                                                        NaN
# Chromosome 2 Start                                                  NaN
# Chromosome 2 Stop                                                   NaN
# Reference Build                                                  GRCh37
# Name: 7, dtype: object
# Gene                                                               KRAS
# Variant Name                                                    G12/G13
# Variant Group(s)                                                    NaN
# Variant Types(s)                               Protein Altering Variant
# Description           While the KRAS G12 region is a widely studied ...
# Chromosome 1                                                         12
# Chromosome 1 Start                                             25398280
# Chromosome 1 Stop                                              25398285
# Chromosome 2                                                        NaN
# Chromosome 2 Start                                                  NaN
# Chromosome 2 Stop                                                   NaN
# Reference Build                                                  GRCh37
# Name: 8, dtype: object
# Gene                                                               FLT3
# Variant Name                                               TKD MUTATION
# Variant Group(s)                                                    NaN
# Variant Types(s)                                  Nonsynonymous Variant
# Description           FLT3 tyrosine kinase domain mutations (FLT3-TK...
# Chromosome 1                                                         13
# Chromosome 1 Start                                             28592642
# Chromosome 1 Stop                                              28592642
# Chromosome 2                                                        NaN
# Chromosome 2 Start                                                  NaN
# Chromosome 2 Stop                                                   NaN
# Reference Build                                                  GRCh37
# Name: 9, dtype: object
# Gene                                                             DNMT3A
# Variant Name                                                   MUTATION
# Variant Group(s)                                                    NaN
# Variant Types(s)                                     Transcript Variant
# Description           DNMT3A mutations occur in a variety of myeloid...
# Chromosome 1                                                          2
# Chromosome 1 Start                                             25455845
# Chromosome 1 Stop                                              25565459
# Chromosome 2                                                        NaN
# Chromosome 2 Start                                                  NaN
# Chromosome 2 Stop                                                   NaN
# Reference Build                                                  GRCh37
# Name: 10, dtype: object
# Gene                                                                KIT
# Variant Name                                            EXON 9 MUTATION
# Variant Group(s)                                                    NaN
# Variant Types(s)                                           Exon Variant
# Description           In patients with gastrointestinal stromal tumo...
# Chromosome 1                                                          4
# Chromosome 1 Start                                             55592023
# Chromosome 1 Stop                                              55592216
# Chromosome 2                                                        NaN
# Chromosome 2 Start                                                  NaN
# Chromosome 2 Stop                                                   NaN
# Reference Build                                                  GRCh37
# Name: 11, dtype: object
# Gene                                                             PIK3CA
# Variant Name                                                   MUTATION
# Variant Group(s)                                                    NaN
# Variant Types(s)           Gain Of Function Variant, Transcript Variant
# Description           PIK3CA mutations are observed in many cancers ...
# Chromosome 1                                                          3
# Chromosome 1 Start                                            178866311
# Chromosome 1 Stop                                             178957881
# Chromosome 2                                                        NaN
# Chromosome 2 Start                                                  NaN
# Chromosome 2 Stop                                                   NaN
# Reference Build                                                  GRCh37
# Name: 12, dtype: object
# Gene                                                          NRAS
# Variant Name                                              MUTATION
# Variant Group(s)                                               NaN
# Variant Types(s)      Gain Of Function Variant, Transcript Variant
# Description                                                    NaN
# Chromosome 1                                                     1
# Chromosome 1 Start                                       115247090
# Chromosome 1 Stop                                        115259515
# Chromosome 2                                                   NaN
# Chromosome 2 Start                                             NaN
# Chromosome 2 Stop                                              NaN
# Reference Build                                             GRCh37
# Name: 13, dtype: object
# Gene                                      TP53
# Variant Name                          MUTATION
# Variant Group(s)                           NaN
# Variant Types(s)      Protein Altering Variant
# Description                                NaN
# Chromosome 1                                17
# Chromosome 1 Start                     7571720
# Chromosome 1 Stop                      7590856
# Chromosome 2                               NaN
# Chromosome 2 Start                         NaN
# Chromosome 2 Stop                          NaN
# Reference Build                         GRCh37
# Name: 14, dtype: object
# Gene                                                               KRAS
# Variant Name                                            EXON 2 MUTATION
# Variant Group(s)                                                    NaN
# Variant Types(s)                                       Missense Variant
# Description           Exon 2 mutations have been associated with red...
# Chromosome 1                                                         12
# Chromosome 1 Start                                             25398208
# Chromosome 1 Stop                                              25398329
# Chromosome 2                                                        NaN
# Chromosome 2 Start                                                  NaN
# Chromosome 2 Stop                                                   NaN
# Reference Build                                                  GRCh37
# Name: 15, dtype: object
# Gene                                      PTEN
# Variant Name                              LOSS
# Variant Group(s)                           NaN
# Variant Types(s)      Loss Of Function Variant
# Description                                NaN
# Chromosome 1                                10
# Chromosome 1 Start                    89622870
# Chromosome 1 Stop                     89731687
# Chromosome 2                               NaN
# Chromosome 2 Start                         NaN
# Chromosome 2 Stop                          NaN
# Reference Build                         GRCh37
# Name: 16, dtype: object
# Gene                             EGFR
# Variant Name                 MUTATION
# Variant Group(s)                  NaN
# Variant Types(s)      Inframe Variant
# Description                       NaN
# Chromosome 1                        7
# Chromosome 1 Start           55086794
# Chromosome 1 Stop            55279321
# Chromosome 2                      NaN
# Chromosome 2 Start                NaN
# Chromosome 2 Stop                 NaN
# Reference Build                GRCh37
# Name: 17, dtype: object
# Gene                                     SF3B1
# Variant Name                          MUTATION
# Variant Group(s)                           NaN
# Variant Types(s)      Protein Altering Variant
# Description                                NaN
# Chromosome 1                                 2
# Chromosome 1 Start                   198254508
# Chromosome 1 Stop                    198299815
# Chromosome 2                               NaN
# Chromosome 2 Start                         NaN
# Chromosome 2 Stop                          NaN
# Reference Build                         GRCh37
# Name: 18, dtype: object
# Gene                                                               EGFR
# Variant Name                                           EXON 19 DELETION
# Variant Group(s)                                                    NaN
# Variant Types(s)                                       Inframe Deletion
# Description           Deletions within exon 19 of EGFR are most comm...
# Chromosome 1                                                          7
# Chromosome 1 Start                                             55242415
# Chromosome 1 Stop                                              55242513
# Chromosome 2                                                        NaN
# Chromosome 2 Start                                                  NaN
# Chromosome 2 Stop                                                   NaN
# Reference Build                                                  GRCh37
# Name: 19, dtype: object
# Gene                                                               FLT3
# Variant Name                                                        ITD
# Variant Group(s)                                                    NaN
# Variant Types(s)                                      Inframe Insertion
# Description           FLT3-ITD (internal tandem duplications) freque...
# Chromosome 1                                                         13
# Chromosome 1 Start                                             28608219
# Chromosome 1 Stop                                              28608351
# Chromosome 2                                                        NaN
# Chromosome 2 Start                                                  NaN
# Chromosome 2 Stop                                                   NaN
# Reference Build                                                  GRCh37
# Name: 20, dtype: object
# Gene                                                                WT1
# Variant Name                                            EXON 7 MUTATION
# Variant Group(s)                                                    NaN
# Variant Types(s)                                           Exon Variant
# Description           WT1 exon 7 mutations have been shown to be rec...
# Chromosome 1                                                         11
# Chromosome 1 Start                                             32417803
# Chromosome 1 Stop                                              32417953
# Chromosome 2                                                        NaN
# Chromosome 2 Start                                                  NaN
# Chromosome 2 Stop                                                   NaN
# Reference Build                                                  GRCh37
# Name: 21, dtype: object
# Gene                                                              FGFR1
# Variant Name                                              AMPLIFICATION
# Variant Group(s)                                                    NaN
# Variant Types(s)                               Transcript Amplification
# Description           FGFR1 amplifications are the most common aberr...
# Chromosome 1                                                          8
# Chromosome 1 Start                                             38268656
# Chromosome 1 Stop                                              38325363
# Chromosome 2                                                        NaN
# Chromosome 2 Start                                                  NaN
# Chromosome 2 Stop                                                   NaN
# Reference Build                                                  GRCh37
# Name: 22, dtype: object
# Gene                                                               TET2
# Variant Name                                                   MUTATION
# Variant Group(s)                                                    NaN
# Variant Types(s)                 Gene Variant, Loss Of Function Variant
# Description           TET2 mutations are commonly found in acute mye...
# Chromosome 1                                                          4
# Chromosome 1 Start                                            106067450
# Chromosome 1 Stop                                             106200973
# Chromosome 2                                                        NaN
# Chromosome 2 Start                                                  NaN
# Chromosome 2 Stop                                                   NaN
# Reference Build                                                  GRCh37
# Name: 23, dtype: object
# Gene                                                               EGFR
# Variant Name                                                      T790M
# Variant Group(s)                                    EGFR TKI Resistance
# Variant Types(s)                                       Missense Variant
# Description           EGFR T790M was one of the very first mutations...
# Chromosome 1                                                          7
# Chromosome 1 Start                                             55249071
# Chromosome 1 Stop                                              55249071
# Chromosome 2                                                        NaN
# Chromosome 2 Start                                                  NaN
# Chromosome 2 Stop                                                   NaN
# Reference Build                                                  GRCh37
# Name: 24, dtype: object
# Gene                                                               ABL1
# Variant Name                                              BCR-ABL T315I
# Variant Group(s)                                    Imatinib Resistance
# Variant Types(s)                    Transcript Fusion, Missense Variant
# Description           While the efficacy of imatinib has revolutioni...
# Chromosome 1                                                          9
# Chromosome 1 Start                                            133748283
# Chromosome 1 Stop                                             133748283
# Chromosome 2                                                        NaN
# Chromosome 2 Start                                                  NaN
# Chromosome 2 Stop                                                   NaN
# Reference Build                                                  GRCh37
# Name: 25, dtype: object
# Gene                                                               KRAS
# Variant Name                                                       G12D
# Variant Group(s)                                    EGFR TKI Resistance
# Variant Types(s)                                       Missense Variant
# Description           While the KRAS G12 region is a widely studied ...
# Chromosome 1                                                         12
# Chromosome 1 Start                                             25398284
# Chromosome 1 Stop                                              25398284
# Chromosome 2                                                        NaN
# Chromosome 2 Start                                                  NaN
# Chromosome 2 Stop                                                   NaN
# Reference Build                                                  GRCh37
# Name: 26, dtype: object
# Gene                                                               EGFR
# Variant Name                                                      L858R
# Variant Group(s)                                                    NaN
# Variant Types(s)                                       Missense Variant
# Description           EGFR L858R has long been recognized as a funct...
# Chromosome 1                                                          7
# Chromosome 1 Start                                             55259515
# Chromosome 1 Stop                                              55259515
# Chromosome 2                                                        NaN
# Chromosome 2 Start                                                  NaN
# Chromosome 2 Stop                                                   NaN
# Reference Build                                                  GRCh37
# Name: 27, dtype: object
# Gene                                                             DNMT3A
# Variant Name                                                       R882
# Variant Group(s)                                                    NaN
# Variant Types(s)                                       Missense Variant
# Description           DNMT3A R882 mutations are associated with cyto...
# Chromosome 1                                                          2
# Chromosome 1 Start                                             25457241
# Chromosome 1 Stop                                              25457243
# Chromosome 2                                                        NaN
# Chromosome 2 Start                                                  NaN
# Chromosome 2 Stop                                                   NaN
# Reference Build                                                  GRCh37
# Name: 28, dtype: object
# Gene                                                               KRAS
# Variant Name                                                        G12
# Variant Group(s)                                                    NaN
# Variant Types(s)                               Protein Altering Variant
# Description           While the KRAS G12 region is a widely studied ...
# Chromosome 1                                                         12
# Chromosome 1 Start                                             25398284
# Chromosome 1 Stop                                              25398285
# Chromosome 2                                                        NaN
# Chromosome 2 Start                                                  NaN
# Chromosome 2 Stop                                                   NaN
# Reference Build                                                  GRCh37
# Name: 29, dtype: object
# Gene                                                   BRCA2
# Variant Name                                        MUTATION
# Variant Group(s)                                         NaN
# Variant Types(s)      Loss Of Function Variant, Gene Variant
# Description                                              NaN
# Chromosome 1                                              13
# Chromosome 1 Start                                  32889611
# Chromosome 1 Stop                                   32973347
# Chromosome 2                                             NaN
# Chromosome 2 Start                                       NaN
# Chromosome 2 Stop                                        NaN
# Reference Build                                       GRCh37
# Name: 30, dtype: object
# Gene                                                   BRCA1
# Variant Name                                        MUTATION
# Variant Group(s)                                         NaN
# Variant Types(s)      Loss Of Function Variant, Gene Variant
# Description                                              NaN
# Chromosome 1                                              17
# Chromosome 1 Start                                  41196312
# Chromosome 1 Stop                                   41277387
# Chromosome 2                                             NaN
# Chromosome 2 Start                                       NaN
# Chromosome 2 Stop                                        NaN
# Reference Build                                       GRCh37
# Name: 31, dtype: object
# Gene                                                              RUNX1
# Variant Name                                                   MUTATION
# Variant Group(s)                                                    NaN
# Variant Types(s)           Transcript Variant, Loss Of Function Variant
# Description           RUNX1 mutations are associated with poor progn...
# Chromosome 1                                                         21
# Chromosome 1 Start                                             36160098
# Chromosome 1 Stop                                              36421641
# Chromosome 2                                                        NaN
# Chromosome 2 Start                                                  NaN
# Chromosome 2 Stop                                                   NaN
# Reference Build                                                  GRCh37
# Name: 32, dtype: object
# Gene                                      KRAS
# Variant Name                          MUTATION
# Variant Group(s)                           NaN
# Variant Types(s)      Protein Altering Variant
# Description                                NaN
# Chromosome 1                                12
# Chromosome 1 Start                    25362365
# Chromosome 1 Stop                     25403737
# Chromosome 2                               NaN
# Chromosome 2 Start                         NaN
# Chromosome 2 Stop                          NaN
# Reference Build                         GRCh37
# Name: 33, dtype: object
# Gene                                                              CEBPA
# Variant Name                                                   MUTATION
# Variant Group(s)                                                    NaN
# Variant Types(s)           Transcript Variant, Loss Of Function Variant
# Description           CEBPA mutations are associated with cytogeneti...
# Chromosome 1                                                         19
# Chromosome 1 Start                                             33790840
# Chromosome 1 Stop                                              33793470
# Chromosome 2                                                        NaN
# Chromosome 2 Start                                                  NaN
# Chromosome 2 Stop                                                   NaN
# Reference Build                                                  GRCh37
# Name: 34, dtype: object
# Gene                                                               NPM1
# Variant Name                                           EXON 12 MUTATION
# Variant Group(s)                                           NPM1 Exon 12
# Variant Types(s)                                           Exon Variant
# Description           NPM1 exon 12 mutations are frequently identifi...
# Chromosome 1                                                          5
# Chromosome 1 Start                                            170837531
# Chromosome 1 Stop                                             170837569
# Chromosome 2                                                        NaN
# Chromosome 2 Start                                                  NaN
# Chromosome 2 Stop                                                   NaN
# Reference Build                                                  GRCh37
# Name: 35, dtype: object
# Gene                                                    BRAF
# Variant Name                                        MUTATION
# Variant Group(s)                                         NaN
# Variant Types(s)      Gain Of Function Variant, Gene Variant
# Description                                              NaN
# Chromosome 1                                               7
# Chromosome 1 Start                                 140453136
# Chromosome 1 Stop                                  140481403
# Chromosome 2                                             NaN
# Chromosome 2 Start                                       NaN
# Chromosome 2 Stop                                        NaN
# Reference Build                                       GRCh37
# Name: 36, dtype: object
# Gene                                                                KIT
# Variant Name                                           EXON 11 MUTATION
# Variant Group(s)                                            KIT Exon 11
# Variant Types(s)                                Coding Sequence Variant
# Description           c-KIT mutations in exon 11 lie within the juxt...
# Chromosome 1                                                          4
# Chromosome 1 Start                                             55593582
# Chromosome 1 Stop                                              55593708
# Chromosome 2                                                        NaN
# Chromosome 2 Start                                                  NaN
# Chromosome 2 Stop                                                   NaN
# Reference Build                                                  GRCh37
# Name: 37, dtype: object
# Gene                              GNAS
# Variant Name                     T393C
# Variant Group(s)                   NaN
# Variant Types(s)      Missense Variant
# Description                        NaN
# Chromosome 1                        20
# Chromosome 1 Start            57428713
# Chromosome 1 Stop             57428713
# Chromosome 2                       NaN
# Chromosome 2 Start                 NaN
# Chromosome 2 Stop                  NaN
# Reference Build                 GRCh37
# Name: 38, dtype: object
# Gene                                                              BRCA2
# Variant Name                                           LOSS-OF-FUNCTION
# Variant Group(s)                                 BRCA Germline Variants
# Variant Types(s)                               Loss Of Function Variant
# Description           BRCA2 loss of function mutations have been sho...
# Chromosome 1                                                         13
# Chromosome 1 Start                                             32889611
# Chromosome 1 Stop                                              32973347
# Chromosome 2                                                        NaN
# Chromosome 2 Start                                                  NaN
# Chromosome 2 Stop                                                   NaN
# Reference Build                                                  GRCh37
# Name: 39, dtype: object
# Gene                                      EGFR
# Variant Name                     AMPLIFICATION
# Variant Group(s)                           NaN
# Variant Types(s)      Transcript Amplification
# Description                                NaN
# Chromosome 1                                 7
# Chromosome 1 Start                    55086794
# Chromosome 1 Stop                     55279321
# Chromosome 2                               NaN
# Chromosome 2 Start                         NaN
# Chromosome 2 Stop                          NaN
# Reference Build                         GRCh37
# Name: 40, dtype: object
# Panel generation has been successfully completed!
